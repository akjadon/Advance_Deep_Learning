# %% [markdown]
# # Train and save a TensorFlow model

# %% [markdown]
# ### Problem Statement
# #### Train a neural network model to classify [images of clothing, like sneakers and shirts](https://github.com/zalandoresearch/fashion-mnist) and save the trained model.

# %% [markdown]
# ### The Fashion MNIST dataset overview
#
# The [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset  contains 70,000 grayscale images in 10 categories. The images show individual articles of clothing at low resolution (28 by 28 pixels), as seen below:
#
# <table>
#   <tr><td>
#     <img src="https://tensorflow.org/images/fashion-mnist-sprite.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1.</b> <a href="https://github.com/zalandoresearch/fashion-mnist">Fashion-MNIST samples</a> (by Zalando, MIT License).<br/>&nbsp;
#   </td></tr>
# </table>
#
# Although these are really images, they are loaded as NumPy arrays and not binary image objects.

# %% [markdown]
# ### Import the libraries

# %%
import tensorflow as tf
import keras

# %% [markdown]
# ### Load the dataset

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
# scale the values to 0.0 to 1.0
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# reshape for feeding into the model
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1)
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
print('\ntrain_images.shape: {}, of {}'.format(train_images.shape, train_images.dtype))
print('test_images.shape: {}, of {}'.format(test_images.shape, test_images.dtype))
# Out:
# train_images.shape: (60000, 28, 28, 1), of float64
# test_images.shape: (10000, 28, 28, 1), of float64

# %% [markdown]
# ### Define the model

# %%
model = keras.Sequential([
  keras.layers.Conv2D(input_shape=(28,28,1), filters=8, kernel_size=3, 
                      strides=2, activation='relu', name='Conv1'),
  keras.layers.Flatten(),
  keras.layers.Dense(10, activation=tf.nn.softmax, name='Softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv1 (Conv2D)               (None, 13, 13, 8)         80
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1352)              0
# _________________________________________________________________
# Softmax (Dense)              (None, 10)                13530
# =================================================================
# Total params: 13,610
# Trainable params: 13,610
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 5

# %%
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=epochs)
# Out:
# WARNING:tensorflow:From /home/judy/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/5
# 60000/60000 [==============================] - 16s 271us/step - loss: 0.5326 - accuracy: 0.8154
# Epoch 2/5
# 60000/60000 [==============================] - 18s 301us/step - loss: 0.3921 - accuracy: 0.8625
# Epoch 3/5
# 60000/60000 [==============================] - 16s 272us/step - loss: 0.3589 - accuracy: 0.8735
# Epoch 4/5
# 60000/60000 [==============================] - 16s 267us/step - loss: 0.3367 - accuracy: 0.8807
# Epoch 5/5
# 60000/60000 [==============================] - 15s 258us/step - loss: 0.3227 - accuracy: 0.8850

# %% [markdown]
# ### Evaluate the model

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('\nTest accuracy: {}'.format(test_acc))
# Out:
# 10000/10000 [==============================] - 2s 183us/step
#
# Test accuracy: 0.8744000196456909

# %% [markdown]
# ## Save the model
#
# You can save your model by calling the save() function on the model and specifying the filename.

# %%
model.save("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
